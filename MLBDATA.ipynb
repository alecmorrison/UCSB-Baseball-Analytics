# %%
import os
import pandas as pd
import numpy as np
import pybaseball
from pybaseball import statcast

# %%
pybaseball.cache.enable()

# %%
data_2017_2021 = statcast('2017-04-02','2021-9-02')
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# Skipping offseason dates
# Skipping offseason dates
# Skipping offseason dates
# 100%|█████████████████████████████████████████| 922/922 [06:17<00:00,  2.44it/s]

# %%
data_2022_2023 = statcast('2022-04-07','2023-05-10')
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# 100%|█████████████████████████████████████████| 280/280 [01:03<00:00,  4.43it/s]

# %%
data_2017_2021
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1899         FF 2021-09-02           92.3           1.22            6.7
# 1981         FF 2021-09-02           93.1           1.21           6.77
# 2033         SL 2021-09-02           80.9           1.49           6.61
# 2118         SL 2021-09-02           82.2           1.58           6.56
# 2140         CU 2021-09-02           76.8           1.41           6.82
# ...         ...        ...            ...            ...            ...
# 789          SI 2017-04-02           98.4          -1.23           5.15
# 807          SL 2017-04-02           84.6          -1.25           5.39
# 844          SI 2017-04-02           97.3          -1.32           5.18
# 880          SI 2017-04-02           95.9          -1.31           5.48
# 911          FF 2017-04-02           94.9          -1.33           5.59
#
#            player_name  batter  pitcher                     events  \
# ...

# %%
data_2022_2023
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2256         SL 2023-05-10           91.3          -0.21           5.88
# 2310         SL 2023-05-10           90.2          -0.03           5.93
# 2383         SL 2023-05-10           90.0          -0.19            5.9
# 2452         SL 2023-05-10           90.8          -0.02           5.92
# 2534         SL 2023-05-10           89.4           -0.1           5.94
# ...         ...        ...            ...            ...            ...
# 1717         FS 2022-04-07           91.8          -1.76           6.04
# 1773         ST 2022-04-07           86.9          -2.29           5.77
# 1872         FF 2022-04-07           99.2          -2.13           5.87
# 1930         FF 2022-04-07           97.9          -2.16           5.89
# 1992         FF 2022-04-07           99.8          -2.19           5.82
#
#          player_name  batter  pitcher     events      description  ...  \
# ...

# %%
data = pd.concat([data_2017_2021, data_2022_2023],ignore_index = True)

# %%
data
# Out:
#         pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0               FF 2021-09-02           92.3           1.22            6.7
# 1               FF 2021-09-02           93.1           1.21           6.77
# 2               SL 2021-09-02           80.9           1.49           6.61
# 3               SL 2021-09-02           82.2           1.58           6.56
# 4               CU 2021-09-02           76.8           1.41           6.82
# ...            ...        ...            ...            ...            ...
# 4042938         FS 2022-04-07           91.8          -1.76           6.04
# 4042939         ST 2022-04-07           86.9          -2.29           5.77
# 4042940         FF 2022-04-07           99.2          -2.13           5.87
# 4042941         FF 2022-04-07           97.9          -2.16           5.89
# 4042942         FF 2022-04-07           99.8          -2.19           5.82
#
# ...

# %%
data.to_csv('/Users/AlecMorrison/Desktop/Schoolwork/UCSB Internship/mlb_data.csv', index = False)

# %%
Dodgers_Data = statcast('2022-04-07','2023-5-11', team = 'LAD')
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# 100%|█████████████████████████████████████████| 281/281 [01:28<00:00,  3.17it/s]

# %%
Dodgers_Data.to_csv('/Users/AlecMorrison/Desktop/Schoolwork/UCSB Internship/Dodgers_Data.csv', index = False)

# %%
Dodgers_Data
# Out:
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 66          CU 2023-05-10           77.8          -3.48           5.93
# 68          CH 2023-05-10           84.6          -3.71           5.69
# 69          FC 2023-05-10           90.3          -3.53           5.72
# 71          CH 2023-05-10           84.0          -3.72           5.67
# 73          CH 2023-05-10           83.9           -3.6           5.74
# ..         ...        ...            ...            ...            ...
# 115         FF 2022-04-08           95.4          -0.81           5.71
# 120         FF 2022-04-08           95.7          -0.95           5.65
# 122         CH 2022-04-08           90.6          -1.19           5.52
# 127         FF 2022-04-08           94.5          -0.72           5.92
# 133         FF 2022-04-08           93.9          -1.01           5.73
#
#          player_name  batter  pitcher     events    description  ...  \
# ...
