# %%
import numpy as np
import pandas as pd

# %%
x = "blackmon_standard.csv"

table = pd.read_csv(x)

# %%
table
# Out:
#     pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0           SL  2022-09-27           83.7          -1.49           4.88
# 1           SI  2022-09-27           91.6          -1.40           4.90
# 2           SI  2022-09-27           96.7          -2.11           5.36
# 3           FF  2022-09-22           92.4           2.29           5.68
# 4           SL  2022-09-21           83.2          -1.68           4.74
# ..         ...         ...            ...            ...            ...
# 201         CU  2020-07-29           84.7           2.36           5.47
# 202         FF  2020-07-29           97.0           2.27           5.86
# 203         FF  2020-07-28           88.5          -1.37           5.61
# 204         FF  2020-07-28           95.0          -1.34           6.04
# 205         FF  2020-07-24           95.2          -2.97           5.75
#
#            player_name  batter  pitcher     events    description  ...  \
# ...

# %%
table["events"]
xbh = 0
count = 0

for x in table["events"]:
    count = count + 1
    if ((x == "triple") or (x == "double")):
        xbh = xbh+1
    

print(xbh)
print(count)

xbhRate = xbh/count
print(xbhRate*100)
# Out:
# 16
# 206
# 7.766990291262135

# %%
xbh/count
